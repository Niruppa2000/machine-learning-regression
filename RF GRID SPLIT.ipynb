# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
 dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
indep
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dep=dataset['charges']
dep
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV

param_grid = { 'criterion' : ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
              'max_features': [0.1, 1.0],
              'n_estimators':[10,100]}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': [0.1, 1.0],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': 1.0, 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.040337      0.002805         0.004969        0.000899
# 1        0.293145      0.007888         0.012713        0.001099
# 2        0.042507      0.000566         0.004050        0.001411
# 3        0.411337      0.006007         0.012201        0.001389
# 4        0.097642      0.003684         0.003382        0.001282
# 5        0.913145      0.015673         0.013480        0.003312
# 6        0.211716      0.003158         0.004419        0.001754
# 7        2.103389      0.018003         0.011222        0.001673
# 8        0.029431      0.002474         0.003106        0.002360
# 9        0.266168      0.003620         0.009768        0.001212
# 10       0.044289      0.007197         0.002619        0.002969
# 11       0.391992      0.010303         0.011225        0.001285
# 12       0.043233      0.001044         0.002313        0.002024
# 13       0.453764      0.009180         0.011592        0.002209
# 14       0.063564      0.002309         0.001995        0.001861
# 15       0.530988      0.032061         0.008676        0.001168
#
#    param_criterion  param_max_features  param_n_estimators  \
# 0    squared_error                 0.1                  10
# 1    squared_error                 0.1                 100
# 2    squared_error                 1.0                  10
# 3    squared_error                 1.0                 100
# 4   absolute_error                 0.1                  10
# 5   absolute_error                 0.1                 100
# 6   absolute_error                 1.0                  10
# 7   absolute_error                 1.0                 100
# 8     friedman_mse                 0.1                  10
# 9     friedman_mse                 0.1                 100
# 10    friedman_mse                 1.0                  10
# 11    friedman_mse                 1.0                 100
# 12         poisson                 0.1                  10
# 13         poisson                 0.1                 100
# 14         poisson                 1.0                  10
# 15         poisson                 1.0                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.838463
# 1   {'criterion': 'squared_error', 'max_features':...           0.844454
# 2   {'criterion': 'squared_error', 'max_features':...           0.837384
# 3   {'criterion': 'squared_error', 'max_features':...           0.847684
# 4   {'criterion': 'absolute_error', 'max_features'...           0.808392
# 5   {'criterion': 'absolute_error', 'max_features'...           0.834900
# 6   {'criterion': 'absolute_error', 'max_features'...           0.832200
# 7   {'criterion': 'absolute_error', 'max_features'...           0.837094
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.837422
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.843324
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.824629
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.843481
# 12  {'criterion': 'poisson', 'max_features': 0.1, ...           0.816589
# 13  {'criterion': 'poisson', 'max_features': 0.1, ...           0.844307
# 14  {'criterion': 'poisson', 'max_features': 1.0, ...           0.835261
# 15  {'criterion': 'poisson', 'max_features': 1.0, ...           0.845461
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.745340           0.816008           0.795955
# 1            0.767169           0.830771           0.814200
# 2            0.756039           0.836857           0.806402
# 3            0.770475           0.848966           0.818504
# 4            0.750112           0.811782           0.772666
# 5            0.770997           0.824346           0.813467
# 6            0.756603           0.825796           0.807849
# 7            0.765126           0.852715           0.824693
# 8            0.742393           0.819892           0.771425
# 9            0.762585           0.834333           0.803214
# 10           0.760826           0.842343           0.799266
# 11           0.772595           0.853158           0.822864
# 12           0.726970           0.820254           0.780431
# 13           0.765076           0.825433           0.811639
# 14           0.773320           0.842159           0.797064
# 15           0.773835           0.860801           0.821524
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.768742         0.792901        0.033060               14
# 1            0.814170         0.814153        0.026084                5
# 2            0.825054         0.812347        0.030315                9
# 3            0.831811         0.823488        0.028772                3
# 4            0.800419         0.788674        0.023681               15
# 5            0.820571         0.812856        0.022045                8
# 6            0.818428         0.808175        0.027028               12
# 7            0.832241         0.822374        0.030058                4
# 8            0.795114         0.793249        0.033844               13
# 9            0.817175         0.812126        0.028375               10
# 10           0.830944         0.811602        0.029049               11
# 11           0.838444         0.826109        0.028495                2
# 12           0.771641         0.783177        0.034032               16
# 13           0.823515         0.813994        0.026604                6
# 14           0.818780         0.813317        0.025327                7
# 15           0.841158         0.828556        0.030094                1

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 23
# BMI: 30
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[24112.2985384]
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
