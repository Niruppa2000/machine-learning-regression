# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
 dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
indep
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dep=dataset['charges']
dep
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = { 'criterion' : ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
              'max_features': [0.1, 1.0],
              'n_estimators':[10,100]}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': [0.1, 1.0],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': 1.0, 'n_estimators': 100}: 0.8591006464823981

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.024960      0.000552         0.003662        0.001885
# 1        0.256722      0.010831         0.010104        0.000303
# 2        0.033700      0.000886         0.002024        0.000026
# 3        0.327600      0.004385         0.010472        0.001752
# 4        0.062133      0.002821         0.002837        0.002391
# 5        0.573025      0.013175         0.009396        0.001358
# 6        0.126369      0.001080         0.001738        0.001543
# 7        1.243419      0.011543         0.011063        0.001187
# 8        0.023506      0.001960         0.003478        0.002497
# 9        0.221638      0.003518         0.010540        0.001753
# 10       0.031865      0.002378         0.001205        0.001127
# 11       0.313555      0.005766         0.009654        0.000650
# 12       0.033394      0.002989         0.002958        0.002320
# 13       0.355771      0.003447         0.008619        0.000958
# 14       0.046366      0.001678         0.002080        0.002288
# 15       0.452083      0.017680         0.015089        0.003407
#
#    param_criterion  param_max_features  param_n_estimators  \
# 0    squared_error                 0.1                  10
# 1    squared_error                 0.1                 100
# 2    squared_error                 1.0                  10
# 3    squared_error                 1.0                 100
# 4   absolute_error                 0.1                  10
# 5   absolute_error                 0.1                 100
# 6   absolute_error                 1.0                  10
# 7   absolute_error                 1.0                 100
# 8     friedman_mse                 0.1                  10
# 9     friedman_mse                 0.1                 100
# 10    friedman_mse                 1.0                  10
# 11    friedman_mse                 1.0                 100
# 12         poisson                 0.1                  10
# 13         poisson                 0.1                 100
# 14         poisson                 1.0                  10
# 15         poisson                 1.0                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.748046
# 1   {'criterion': 'squared_error', 'max_features':...           0.773006
# 2   {'criterion': 'squared_error', 'max_features':...           0.765650
# 3   {'criterion': 'squared_error', 'max_features':...           0.802544
# 4   {'criterion': 'absolute_error', 'max_features'...           0.770246
# 5   {'criterion': 'absolute_error', 'max_features'...           0.790855
# 6   {'criterion': 'absolute_error', 'max_features'...           0.758335
# 7   {'criterion': 'absolute_error', 'max_features'...           0.783545
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.778232
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.781965
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.792838
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.803229
# 12  {'criterion': 'poisson', 'max_features': 0.1, ...           0.780922
# 13  {'criterion': 'poisson', 'max_features': 0.1, ...           0.782073
# 14  {'criterion': 'poisson', 'max_features': 1.0, ...           0.790844
# 15  {'criterion': 'poisson', 'max_features': 1.0, ...           0.807951
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.693583           0.814705           0.759983
# 1            0.742522           0.811379           0.814513
# 2            0.668901           0.807661           0.797032
# 3            0.751508           0.829677           0.798759
# 4            0.736379           0.790674           0.760180
# 5            0.748116           0.820113           0.803166
# 6            0.735140           0.818266           0.808954
# 7            0.770781           0.817409           0.802068
# 8            0.721760           0.787513           0.798241
# 9            0.731000           0.796335           0.817639
# 10           0.745383           0.815956           0.771051
# 11           0.755457           0.831086           0.810709
# 12           0.705719           0.794859           0.807995
# 13           0.737979           0.808686           0.806797
# 14           0.744072           0.829986           0.781474
# 15           0.760555           0.836964           0.812432
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.673427         0.737949        0.050220               16
# 1            0.736855         0.775655        0.032853                8
# 2            0.747690         0.757387        0.049176               14
# 3            0.764007         0.789299        0.028154                3
# 4            0.737993         0.759095        0.020416               12
# 5            0.731279         0.778706        0.033602                6
# 6            0.745928         0.773325        0.033830                9
# 7            0.760140         0.786789        0.020727                4
# 8            0.698695         0.756888        0.039304               15
# 9            0.720563         0.769500        0.037603               11
# 10           0.758698         0.776785        0.025052                7
# 11           0.765949         0.793286        0.028318                2
# 12           0.698557         0.757610        0.046151               13
# 13           0.729353         0.772978        0.033555               10
# 14           0.751571         0.779589        0.030713                5
# 15           0.763534         0.796287        0.029668                1

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 23
# BMI: 30
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[57097.2308606]

# %%
import pickle 
filename="finalized_model_Forest.sav"

# %%
pickle.dump(grid,open(filename,'wb'))

# %%
preinput=sc.transform([[23,30,2,1,1]])
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
loaded_model=pickle.load(open("finalized_model_Forest.sav",'rb')) #loading the final model and prediction
result=loaded_model.predict([[23,30,2,1,1]])

# %%
result
# Out:
# array([57097.2308606])
